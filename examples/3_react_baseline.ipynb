# %%
from langchain_openai import ChatOpenAI
from fp2mp_baselines import ReactBaseline
from fp2mp_baselines.config import config

def init_llm(model: str, temperature: float = 0.5):
    return ChatOpenAI(
        model=model,
        base_url=config.base_url,
        api_key=config.api_key,
        temperature=temperature,
    )

task = "Город Санкт-Петербург. Разработай план уплотнения городского центра."

# %%
llm = init_llm("deepseek/deepseek-v4-flash")
baseline = ReactBaseline(llm=llm)
state = baseline.invoke_state(task)

# %%
print(state["output"])
# Out:
# Теперь, опираясь на собранную информацию, представляю развёрнутый план.
#
# ---
#
# # ПЛАН УПЛОТНЕНИЯ ГОРОДСКОГО ЦЕНТРА САНКТ-ПЕТЕРБУРГА
#
# ## 1. АНАЛИЗ ИСХОДНОЙ СИТУАЦИИ И НОРМАТИВНО-ПРАВОВАЯ БАЗА
#
# Прежде чем приступить к разработке плана, необходимо зафиксировать **ключевые ограничения**, действующие в центральных районах (Центральный, Петроградский, Василеостровский, Адмиралтейский):
#
# | Фактор | Характеристика |
# |--------|---------------|
# | **Высотный регламент** | Исторически — не выше карниза Зимнего дворца (~23,5 м). Закон №820-7 (2009 г.) делит центр на зоны высотного регулирования от 12 до 48 м, но в «сердце» центра — строгие 12–23 м |
# | **Объединённые зоны охраны ОКН** | Исторически сложившиеся центральные районы — особая зона с наиболее строгими режимами |
# | **Генеральный план 2024–2050** | Принят 21.12.2023. Курс на сбалансированное развитие, но с акцентом на сохранение наследия |
# | **Новые ПЗЗ (2025)** | Ужесточение регламентов, уточнение границ зон, видов разрешённого использования |
# | **Программа КРТ** | Комплексное развитие территорий — реновация кварталов исторического центра |
#
# ---
#
# ## 2. СТРАТЕГИЧЕСКИЕ ПРИНЦИПЫ УПЛОТНЕНИЯ
#
# ### 2.1. «Умное уплотнение» (Smart Densification)
# Не «уплотнительная застройка» в негативном смысле (точечная, хаотичная), а **контролируемое повышение интенсивности использования территории** при сохранении исторического облика.
#
# ### 2.2. Ключевые принципы:
# 1. **Не навреди** — сохранение исторического силуэта и панорам (видовые коридоры на доминанты)
# 2. **Качество среды важнее квадратных метров**
# 3. **Приоритет общественных пространств** над коммерческой застройкой
# 4. **Инфраструктура опережает застройку**
# 5. **Баланс жилых и общественно-деловых функций**
#
# ---
#
# ## 3. ПОЭТАПНЫЙ ПЛАН ДЕЙСТВИЙ
#
# ### ЭТАП 1. ЗОНИРОВАНИЕ И КЛАССИФИКАЦИЯ ТЕРРИТОРИЙ ЦЕНТРА
#
# Разделить центр на три категории по допустимой степени уплотнения:
#
# | Категория | Зона | Допустимое уплотнение | Высотность |
# |-----------|------|----------------------|------------|
# | **«Музейное ядро»** | Центральный р-н (внутри обводного канала), Петроградская сторона (историческая часть), Стрелка В.О. | Минимальное (реставрация + подземные объёмы) | Строго до 23 м |
# | **«Буферная зона»** | Периферия центральных районов, бывшие промышленные зоны | Умеренное (до 25–40% КИНЖ) | До 33–40 м |
# | **«Зона трансформации»** | Бывшие промзоны в центре: «Арсенал», завод «Вулкан», «Красный треугольник», портовые территории В.О. | Значительное (реорганизация, КРТ) | До 48 м (с проработкой силуэта) |
#
# ### ЭТАП 2. ВЫЯВЛЕНИЕ РЕСУРСОВ ДЛЯ УПЛОТНЕНИЯ
#
# #### 2.1. Внутриквартальные территории
# - Провести тотальную инвентаризацию всех пустующих и неэффективно используемых участков (по примеру инвентаризации 40 объектов, которую проводил Смольный)
# - Выявить:
#   - Дворовые пространства-«пустыри» (не имеющие исторической ценности)
#   - Крыши и технические этажи (надстройка мансард)
#   - Подземное пространство (паркинги, общественные функции)
#
# #### 2.2. Бывшие промышленные зоны
# Основной ресурс для уплотнения без ущерба для исторической среды. В центре сохраняется **более 20 бывших промзон** (1-й и 2-й пояс):
#
# | Объект | Площадь | Потенциал |
# |--------|---------|-----------|
# | «Красный треугольник» | ~60 га | Креативные кластеры + жильё + общественные пространства |
# | «Новая Голландия» (завершение) | 7,8 га | Уже реализуется |
# | «Арсенал» (Выборгская сторона) | ~15 га | Жилая + общественная застройка |
# | Территории Васильевского острова (Севастопольская, Морская набережные) | ~200 га | Масштабное КРТ |
#
# #### 2.3. Ветхий жилой фонд
# - Выявить кварталы дореволюционной застройки с «неценными» историческими зданиями (постройки конца XIX – начала XX века без статуса ОКН, находящиеся в аварийном состоянии)
# - Запустить механизм **КРТ** (Комплексное развитие территорий)
#
# ### ЭТАП 3. ИНСТРУМЕНТЫ УПЛОТНЕНИЯ
#
# #### 3.1. Юридические инструменты
#
# **А) Изменение ПЗЗ (2025–2026):**
# - Для «буферной зоны»: увеличить коэффициент интенсивности использования земельных участков (КИНЖ) с 1,5 до 2,0–2,5 при условии сохранения фасадов
# - Ввести бонусы: +20% площади при условии создания общественного пространства на 1-м этаже
#
# **Б) КРТ (Комплексное развитие территорий):**
# - Определить пилотные кварталы КРТ в историческом центре (по аналогии с Москвой)
# - Условия: сохранение исторических фасадов, снос дворовых флигелей-«сараев», новое строительство в глубине квартала
#
# **В) Государственно-частное партнёрство (ГЧП):**
# - Привлечение инвесторов к реновации кварталов под обязательство увеличить площадь (например, «реставрация фасада + надстройка мансарды + подземный этаж»)
#
# #### 3.2. Архитектурно-градостроительные инструменты
#
# **А) «Парящее» уплотнение (надстройка мансард):**
# - Разрешить надстройку мансардных этажей на неценных исторических зданиях (без статуса ОКН)
# - Ограничение: не выше конька крыши соседних ценных зданий
# - Материалы: только лёгкие конструкции, не нарушающие несущие стены
#
# **Б) Подземное уплотнение:**
# - Освоение подземного пространства под дворами-колодцами (2–3 уровня подземных паркингов, коммерческих помещений)
# - Условие: не затрагивать фундаменты ОКН
#
# **В) Реконструкция дворовых флигелей:**
# - Снос малоценных поздних пристроек (советского периода) и возведение современных корпусов в глубине квартала
# - Высотность: не выше окружающей исторической застройки
#
# #### 3.3. Инфраструктурные решения
#
# **Проблема:** транспортная перегрузка центра (все исторические улицы узкие).
#
# **Решение:**
# - Запрет на новое жилое строительство без подтверждения инфраструктурной ёмкости
# - Создание «карты транспортной ёмкости» центра с лимитами на количество новых жителей/сотрудников
# - Строительство перехватывающих паркингов на въезде в центр
# - Развитие велоинфраструктуры и пешеходных зон для снижения автомобилизации
#
# ---
#
# ## 4. КОНКРЕТНЫЕ ПРОЕКТЫ ПО РАЙОНАМ
#
# ### Адмиралтейский район
# | Проект | Характер уплотнения |
# |--------|---------------------|
# | Коломна (Сенная пл. — р. Пряжка) | Реновация кварталов с сохранением исторических фасадов, надстройка мансард |
# | Промзона «Красный треугольник» | Создание нового квартала с жильём, офисами, креативными пространствами |
#
# ### Петроградский район
# | Проект | Характер уплотнения |
# |--------|---------------------|
# | Район ул. Льва Толстого | Точечная застройка (завершение существующих кварталов) |
# | Промзоны: «Вулкан», «Ленполиграфмаш» | Редевелопмент под деловые и жилые кварталы |
#
# ### Василеостровский район
# | Проект | Характер уплотнения |
# |--------|---------------------|
# | Морская набережная | Масштабное КРТ с высотностью до 48 м |
# | Гавань (район Смоленки) | Умеренное уплотнение, общественные пространства |
#
# ### Центральный район
# | Проект | Характер уплотнения |
# |--------|---------------------|
# | Конюшенная площадь | Реновация, подземный паркинг, благоустройство |
# | Пески (р-н ул. Восстания, Кирочная) | Комплексная реновация кварталов |
#
# ---
#
# ## 5. МЕХАНИЗМ КОНТРОЛЯ И ПРОТИВОДЕЙСТВИЕ ТОЧЕЧНОЙ ЗАСТРОЙКЕ
#
# ### 5.1. Запрещённые формы уплотнения:
# - Уплотнение внутри дворов-колодцев исторических зданий
# - Надстройка этажей на зданиях-памятниках
# - Новое строительство, перекрывающее видовые коридоры на доминанты
# - Застройка скверов, садов и парков (независимо от статуса)
#
# ### 5.2. Институты общественного контроля:
# - Обязательные public hearings (общественные слушания) по всем проектам КРТ и новому строительству в центре
# - Введение **Градостроительного совета при Губернаторе** с обязательным участием градозащитников
# - Публикация всех проектов на Градостроительном портале СПб
#
# ---
#
# ## 6. ОЖИДАЕМЫЕ РЕЗУЛЬТАТЫ (2050 г.)
#
# | Параметр | Целевой показатель |
# |----------|-------------------|
# | Прирост жилого фонда в центре | +15–20% (в основном за счёт промзон и мансард) |
# | Доля нового строительства на бывших промзонах | 70% всего нового объёма |
# | Снижение ветхого фонда | С 12% до 3% |
# | Прирост общественных пространств | +40% (за счёт освобождения дворов от «уплотнительных» вставок 1990–2010-х) |
# | Сохранение высотного силуэта | 100% видовых коридоров сохранены |
#
# ---
#
# ## 7. КЛЮЧЕВЫЕ РИСКИ И ИХ МИНИМИЗАЦИЯ
#
# | Риск | Мера |
# |------|------|
# | **«Злоуплотнение»** (точечная застройка под видом реновации) | Ужесточение ПЗЗ, обязательный градсовет, общественный контроль |
# | **Джентрификация** (вытеснение жителей) | Квоты на социальное жильё в новых проектах (не менее 20%) |
# | **Перегрузка инфраструктуры** | Запрет на ввод жилья без синхронного ввода социальных объектов |
# | **Утрата исторического облика** | Строжайший контроль фасадов; только «восстановление» или «стилизация», без хай-тека в центре |
#
# ---
#
# ## 8. ЗАКЛЮЧЕНИЕ
#
# Уплотнение центра Санкт-Петербурга **возможно и необходимо**, но исключительно в форме **контролируемого, соразмерного развития**, а не хаотичной точечной застройки 1990–2000-х годов.
#
# **Главный ресурс уплотнения** — не дворы и не зелёные зоны, а:
# 1. Бывшие промышленные территории (самые крупные резервы)
# 2. Подземное пространство
# 3. Надстройка мансард на неценных зданиях
# 4. Замена ветхих дворовых флигелей на современные корпуса в глубине кварталов
#
# При соблюдении норм Закона №820-7 (зоны охраны), высотного регламента и нового Генерального плана, Санкт-Петербург может получить **+15–20% полезных площадей в центре без ущерба для своего уникального исторического облика**.

# %%
state["log"]

# %%
state["messages"]
