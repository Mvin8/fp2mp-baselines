# %%
from langchain_openai import ChatOpenAI
from fp2mp_baselines import SingleAgentBaseline
from fp2mp_baselines.config import config

def init_llm(model: str, temperature: float = 0.5):
    return ChatOpenAI(
        model=model,
        base_url=config.base_url,
        api_key=config.api_key,
        temperature=temperature,
    )

task = "Город Санкт-Петербург. Разработай план уплотнения городского центра."

# %%
llm = init_llm("deepseek/deepseek-v4-flash")

baseline = SingleAgentBaseline(llm=llm)
state = baseline.invoke_state(task)

# %%
print(state["output"])
# Out:
# Это запрос на разработку концепции, которая в реальности вызывает острейшие дискуссии между градозащитниками, девелоперами и городскими властями. План уплотнения центра Санкт-Петербурга должен быть не «ковровым сносом», а **"мягкой реновацией"** с соблюдением строгих высотных регламентов и охранных зон ЮНЕСКО.
#
# Вот реалистичный, но амбициозный план действий, разделенный на этапы и зоны.
#
# ### I. Исходные принципы (Red Lines)
#
# 1.  **Неприкосновенность охранных зон:** Запрет на любое новое строительство на участках, где оно изменит панорамы Невы, вид на Исаакий, Петропавловку, Стрелку В.О. Высота — жестко 28-30 метров (исторический карниз).
# 2.  **Нормальный Класс Жилья:** Уплотнение не должно превращать центр в «золотой гетто». План должен включать арендное жилье (доходные дома XXI века) и социальную инфраструктуру.
# 3.  **Фокус на "Сером поясе":** Основная зона приложения усилий — не исторические кварталы XVIII-XIX вв., а промзоны и депрессивные районы вдоль Обводного канала, Лиговки, Финляндского вокзала и Васильевского острова (Гавань).
#
# ### II. Этапы реализации плана
#
# #### Этап 1: Аудит и "Снятие запретов" (1-2 года)
#
# *   **Инвентаризация дворов-колодцев:** Выявление неиспользуемых внутренних пространств (мусорки, старые котельные, захламленные проезды), которые можно надстроить или застроить без ущерба для инсоляции (солнечного света) соседних квартир.
# *   **Разрешение на мансарды и надстройки:** Легализация и стимулирование надстройки 2-3 этажей (мансарды) на зданиях эпохи конструктивизма и сталинского ампира (напр., на Московском пр., наб. Обводного), где исторический облик менее чувствителен.
# *   **Включение "скрытых территорий":** Принятие закона об освоении **"пятен застройки"** — неудобных участков, образовавшихся при сносе промышленных корпусов, которые сейчас пустуют (бывшие трамвайные парки, склады на Васильевском).
#
# #### Этап 2: Основные "полигоны уплотнения" (3-7 лет)
#
# 1.  **Намыв Васильевского острова (Морской фасад):**
#     *   *Цель:* Создание "анти-Центра". Высокая плотность (не выше 40-50 м), но с гектарами парков, общественных пространств и собственными школами.
#     *   *Механизм:* Строгий градостроительный план с обязательной долей социального жилья и офисов класса B+.
# 2.  **Обводный канал (от Боровой до Атаманской):**
#     *   *Цель:* Превращение "ржавого пояса" в "пояс жизни".
#     *   *Действия:* Снос ветхих заводских цехов, строительство кварталов смешанной этажности (8-12 этажей) с проходными дворами, магазинами в первых этажах и подземными паркингами. Сохранение краснокирпичных фасадов бывших заводов (лофты).
# 3.  **Территории "Сталинок" (Московский пр., пр. Стачек, пр. Большевиков):**
#     *   *Действия:* Надстройка мансардных этажей (групповая реконструкция), встройка жилых "вставок" между домами, где есть разрывы.
#
# #### Этап 3: Точечное "высокоплотное" освоение (8-10 лет)
#
# *   **"Петербургские дворики":** Застройка внутренних дворов крупных кварталов (на Петроградской стороне, на Юго-Западе). Не небоскребами, а 5-7-этажными "каре" с проездными арками, замыкающими квартал. Это дает увеличение жилой площади без потери исторической планировки.
# *   **Реконструкция школ и больниц:** Снос советских пристроек типовых школ и строительство на их месте многофункциональных зданий (школа+фитнес+офисы мелкого бизнеса).
#
# ### III. Инструменты и "Зеленые меры" (компенсация)
#
# Уплотнение центра вызовет протест. Необходим пакет компенсаций:
#
# 1.  **Жилье "по принципу "стена в стену":** Застройщик, получающий участок в центре, обязан передать городу 15-20% квартир под арендное жилье для бюджетников (врачей, учителей) по цене ниже рыночной.
# 2.  **Правило "Квартал: пол-двора - парк":** Новый квартал должен иметь обязательный озелененный внутренний двор (минимум 40% площади участка). Крыши - эксплуатируемые (сад на крыше).
# 3.  **Создание "Зеленого пояса" над уплотнением:**
#     *   В каждом новом квартале на крыше паркинг (1-й этаж), выше - жилье, но вдоль улиц разбиты бульвары.
#     *   Расширение тротуаров на 2 метра за счет сужения проезжей части.
# 4.  **Сохранение идентичности:**
#     *   Утверждение Фонда фасадов. Любая новая постройка в центре должна иметь "петербургский" облик (штукатурка, лепнина, историческая расстекловка окон, запрет на тонировку стекол и кондиционеры на фасадах).
#
# ### IV. Что делать НЕЛЬЗЯ (критический пункт)
#
# 1.  **Запрет на уплотнение в границах Консульской зоны:** Вся территория внутри Лиговского пр. - ул. Марата - Невского пр. Нельзя.
# 2.  **Запрет на снос доходных домов XIX века** даже в аварийном состоянии (только реконструкция).
# 3.  **Запрет на высотные доминанты (выше 40 м)** в радиусе 2 км от Адмиралтейства.
#
# ### V. Экономический эффект (для города)
#
# *   **Доход бюджета:** Продажа прав на уплотнение "скрытых" участков (аукционы на достройку дворов-колодцев) принесет 100-150 млрд руб. за 10 лет.
# *   **Рабочие места:** Создание 30 000 рабочих мест в строительстве и смежных сферах.
# *   **Решение транспортного коллапса:** Уплотнение центра требует одновременного развития метро (кольцевая линия), перехватывающих парковок на въездах (Парнас, Ржевка) и платного въезда в Центр (только для резидентов).
#
# ### Итоговый вывод
#
# План уплотнения центра Санкт-Петербурга — это не про строительство муравейников. Это про **ремедиацию постиндустриального наследия**, возвращение жилой функции в центр (чтобы улицы не пустели после 20:00) и **строгий дизайн-код**.
#
# **Ключевая формула:** *Уплотняем не исторический центр, а его периферию (Обводной, намыв, промзоны), делая ее более человечной по масштабу и функционально насыщенной.*
#
# Пример для подражания: не Москва-Сити, а кварталы района **"Хафен-Сити" в Гамбурге** — высокая плотность, вода, история и современная архитектура в одном флаконе.

# %%
state["log"]
# Out:
# [HumanMessage(content='Город Санкт-Петербург. Разработай план уплотнения городского центра.', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Это запрос на разработку концепции, которая в реальности вызывает острейшие дискуссии между градозащитниками, девелоперами и городскими властями. План уплотнения центра Санкт-Петербурга должен быть не «ковровым сносом», а **"мягкой реновацией"** с соблюдением строгих высотных регламентов и охранных зон ЮНЕСКО.\n\nВот реалистичный, но амбициозный план действий, разделенный на этапы и зоны.\n\n### I. Исходные принципы (Red Lines)\n\n1.  **Неприкосновенность охранных зон:** Запрет на любое новое строительство на участках, где оно изменит панорамы Невы, вид на Исаакий, Петропавловку, Стрелку В.О. Высота — жестко 28-30 метров (исторический карниз).\n2.  **Нормальный Класс Жилья:** Уплотнение не должно превращать центр в «золотой гетто». План должен включать арендное жилье (доходные дома XXI века) и социальную инфраструктуру.\n3.  **Фокус на "Сером поясе":** Основная зона приложения усилий — не исторические кварталы XVIII-XIX вв., а промзоны и депрессивные районы вдоль Обводного канала, Лиговки, Финляндского вокзала и Васильевского острова (Гавань).\n\n### II. Этапы реализации плана\n\n#### Этап 1: Аудит и "Снятие запретов" (1-2 года)\n\n*   **Инвентаризация дворов-колодцев:** Выявление неиспользуемых внутренних пространств (мусорки, старые котельные, захламленные проезды), которые можно надстроить или застроить без ущерба для инсоляции (солнечного света) соседних квартир.\n*   **Разрешение на мансарды и надстройки:** Легализация и стимулирование надстройки 2-3 этажей (мансарды) на зданиях эпохи конструктивизма и сталинского ампира (напр., на Московском пр., наб. Обводного), где исторический облик менее чувствителен.\n*   **Включение "скрытых территорий":** Принятие закона об освоении **"пятен застройки"** — неудобных участков, образовавшихся при сносе промышленных корпусов, которые сейчас пустуют (бывшие трамвайные парки, склады на Васильевском).\n\n#### Этап 2: Основные "полигоны уплотнения" (3-7 лет)\n\n1.  **Намыв Васильевского острова (Морской фасад):**\n    *   *Цель:* Создание "анти-Центра". Высокая плотность (не выше 40-50 м), но с гектарами парков, общественных пространств и собственными школами.\n    *   *Механизм:* Строгий градостроительный план с обязательной долей социального жилья и офисов класса B+.\n2.  **Обводный канал (от Боровой до Атаманской):**\n    *   *Цель:* Превращение "ржавого пояса" в "пояс жизни".\n    *   *Действия:* Снос ветхих заводских цехов, строительство кварталов смешанной этажности (8-12 этажей) с проходными дворами, магазинами в первых этажах и подземными паркингами. Сохранение краснокирпичных фасадов бывших заводов (лофты).\n3.  **Территории "Сталинок" (Московский пр., пр. Стачек, пр. Большевиков):**\n    *   *Действия:* Надстройка мансардных этажей (групповая реконструкция), встройка жилых "вставок" между домами, где есть разрывы.\n\n#### Этап 3: Точечное "высокоплотное" освоение (8-10 лет)\n\n*   **"Петербургские дворики":** Застройка внутренних дворов крупных кварталов (на Петроградской стороне, на Юго-Западе). Не небоскребами, а 5-7-этажными "каре" с проездными арками, замыкающими квартал. Это дает увеличение жилой площади без потери исторической планировки.\n*   **Реконструкция школ и больниц:** Снос советских пристроек типовых школ и строительство на их месте многофункциональных зданий (школа+фитнес+офисы мелкого бизнеса).\n\n### III. Инструменты и "Зеленые меры" (компенсация)\n\nУплотнение центра вызовет протест. Необходим пакет компенсаций:\n\n1.  **Жилье "по принципу "стена в стену":** Застройщик, получающий участок в центре, обязан передать городу 15-20% квартир под арендное жилье для бюджетников (врачей, учителей) по цене ниже рыночной.\n2.  **Правило "Квартал: пол-двора - парк":** Новый квартал должен иметь обязательный озелененный внутренний двор (минимум 40% площади участка). Крыши - эксплуатируемые (сад на крыше).\n3.  **Создание "Зеленого пояса" над уплотнением:**\n    *   В каждом новом квартале на крыше паркинг (1-й этаж), выше - жилье, но вдоль улиц разбиты ...
