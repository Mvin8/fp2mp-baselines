# %%
from langchain_openai import ChatOpenAI
from fp2mp_baselines import SingleAgentBaseline
from fp2mp_baselines.config import config

def init_llm(model: str, temperature: float = 0.5):
    return ChatOpenAI(
        model=model,
        base_url=config.base_url,
        api_key=config.api_key,
        temperature=temperature,
    )

task = "Город Санкт-Петербург. Разработай план уплотнения городского центра."

# %%
llm = init_llm("deepseek/deepseek-v4-flash")

baseline = SingleAgentBaseline(llm=llm)
state = baseline.invoke_state(task)

# %%
print(state["output"])
# Out:
# Разработка плана уплотнения исторического центра Санкт-Петербурга — задача исключительной сложности. Город-музей под открытым небом, объект Всемирного наследия ЮНЕСКО, имеет жесткие ограничения по высотности (не выше 40 метров, а в центре — до 23–28 м) и охраняемую застройку. «Уплотнение» здесь не может означать «точечную застройку пустырей 25-этажными домами» — это уничтожит идентичность.
#
# Вот реалистичный и этичный **План «умного» уплотнения и ревитализации центра**, основанный на принципах человекоориентированного урбанизма и сохранения наследия.
#
# ---
#
# ### Этап 1: Диагностика и инвентаризация (Год 0)
#
# Прежде чем строить, нужно понять, что *уже* есть.
# - **Аудит пустующих площадей:** Инвентаризация пустующих чердаков, подвалов, дворовых флигелей и промышленных зон (бывшие фабрики). В центре до 30% площадей может быть не использовано.
# - **Карта деградации:** Выявление кварталов с максимальным износом фонда (например, часть Выборгской стороны, Адмиралтейского района), где уплотнение будет сочетаться с реновацией.
# - **Анализ трафика:** Понимание, где уплотнение жилья *ухудшит* ситуацию в час пик, а где (рядом с новыми станциями метро) — улучшит.
#
# ### Этап 2: Зонирование (Правила игры)
#
# Центр делим на 3 зоны с разными режимами уплотнения:
#
# **1. Заповедная зона (ЮНЕСКО + Охранные зоны)** — *80% площади центра.*
# - **Что нельзя:** Снос фасадов, изменение высоты, новые «встройки» в лицевые корпуса.
# - **Как уплотнять:**
#     - **«Капсульная» реконструкция двора:** Снос ветхих, неисторических сараев и советских пристроек во дворах. Возведение малоэтажных (2-4 этажа) современных корпусов из стекла и «кирпичного» алюминия, которые не конкурируют с исторической застройкой (пример: проект Roof Top в Париже).
#     - **Мансарды:** Надстройка мансардных этажей строго в габаритах крыш (без поднятия конька) с использованием легких конструкций. Только там, где есть стилобат или технический чердак.
#     - **Подземное уплотнение:** Строительство подземных паркингов, фитнес-клубов, складов под дворами. Проблема — обводненность грунта, но технологии «стена в грунте» позволяют.
#
# **2. Зона точечной реновации (Трансформация)** — *15% площади.*
# - **Где:** Территории бывших заводов («Красный треугольник», часть «Скорохода») и кварталы с полностью утраченной исторической тканью (например, Конюшенная площадь, застроенная в 1970-х).
# - **Как уплотнять:**
#     - **Полифункциональные кварталы:** Максимум 9-12 этажей. Сочетание жилья (30%), офисов (30%), соц. инфраструктуры (детсады, поликлиники — 20%), ретейла и парков (20%).
#     - **«Суперблоки»:** Объединение 2-3 дворов в пешеходные зоны. Запрет транзитного трафика внутри квартала.
#
# **3. Зона «коридоров развития» (Транспортные магистрали)** — *5% площади.*
# - **Где:** Вдоль Московского проспекта (южнее Обводного), набережные за пределами центра (например, часть Пироговской). Здесь допустима высота до 30-40 метров при условии ступенчатого отступа от исторической застройки.
#
# ---
#
# ### Этап 3: Инструменты и механизмы
#
# 1.  **Правовой лифтинг (Floor Area Ratio - FAR):** Увеличение разрешенной площади застройки (коэффициента плотности) *только* для тех, кто передает городу 30-40% площадей под соц. инфраструктуру или реставрацию аварийных памятников в том же квартале.
# 2.  **Аренда чердаков/подвалов:** Разрешение на перевод технических этажей в жилье/апартаменты (при условии пожарной безопасности). Продажа таких лотов под держателями 49-летней аренды. Это даст жилье без внешнего изменения облика.
# 3.  **Программа «Фасад-Крыша»:** Субсидирование 70% затрат на восстановление фасадов в обмен на разрешение использовать дворовые флигели под современное жилье.
#
# ### Этап 4: Транспорт и экология (Ключевое условие)
#
# Без решения проблемы парковки любое уплотнение убьет центр.
# - **Паркинг вместо ванн:** Снос части дореволюционных гаражей и автосервисов во дворах. Строительство автоматизированных подземных паркингов (на 200-300 машин) на глубине 15-20 м под новыми домами.
# - **Платная парковка:** Расширение платной зоны на весь Центральный и Петроградский районы.
# - **«Зеленый каркас»:** Каждый новый проект обязан компенсировать снос деревьев посадкой на кровле (тротуарное озеленение) или созданием мини-сквера (300 кв.м на 1000 кв.м новой жилой площади).
#
# ### Пример конкретного квартала: «Сенная – Садовая»
#
# *Проблема: Перенаселение, хаотичная торговля, отсутствие дворов.*
#
# **План уплотнения:**
# 1. **Расчистка двора:** Снос ларьков и незаконных пристроек. На их месте — компактный (6 эт.) жилой дом для расселения аварийных квартир из соседних домов.
# 2. **Подземный этаж:** Под двором — паркинг на 50 машин + общественный центр (коворкинг, спортзал для жителей).
# 3. **Крыша:** Эксплуатируемая кровля с садом и детской площадкой.
# 4. **Фасады:** Восстановление лепнины на соседних домах за счет аренды мансарды.
#
# ### Что категорически нельзя делать в рамках уплотнения:
#
# 1. **Сносить исторические лицевые корпуса** (кроме пост-советских вставок).
# 2. **Строить «свечки»** (высотки) рядом с каналами.
# 3. **Застраивать скверы** (Александровский сад, Таврический).
# 4. **Игнорировать инсоляцию** (не затенять окна соседних исторических домов).
#
# ### Итог:
#
# Уплотнение Петербурга — это не про **больше бетона**, а про **качественное сжатие** в рамках уже существующих кварталов. Увеличить жилую площадь можно на 15-20% (пустующие чердаки, подвалы, дворы) без разрушения силуэта города. Главный риск — коррупция и серые схемы точечной застройки. План сработает только при жестком общественном контроле и цифровизации градостроительных решений (публичные реестры высот, инсоляции).

# %%
state["log"]
