# %%
from langchain_openai import ChatOpenAI
from fp2mp_baselines import CotBaseline
from fp2mp_baselines.config import config

def init_llm(model: str, temperature: float = 0.5):
    return ChatOpenAI(
        model=model,
        base_url=config.base_url,
        api_key=config.api_key,
        temperature=temperature,
    )

task = "Город Санкт-Петербург. Разработай план уплотнения городского центра."

# %%
llm = init_llm("deepseek/deepseek-v4-flash")
baseline = CotBaseline(llm=llm)
state = baseline.invoke_state(task)

# %%
print(state["reasoning_summary"])
# Out:
# Ниже представлен структурированный **reasoning** (рассуждение) для разработки плана уплотнения центра Санкт-Петербурга.
#
# ---
#
# ### 1. Допущения (Assumptions)
#
# *   **Сохранение статуса ЮНЕСКО:** Мы исходим из того, что исторический центр является объектом Всемирного наследия. Любое уплотнение не должно нарушать охранные зоны, высотные регламенты и визуальные бассейны (панорамы Невы).
# *   **Существующая инфраструктура:** Инженерные сети (канализация, водоснабжение, электричество) и транспортная сеть центра исторически перегружены. Мы предполагаем, что их модернизация будет синхронизирована с уплотнением, а не следовать за ним постфактум.
# *   **Правовая база:** Законы о защите памятников (ФЗ-73) и местные правила землепользования и застройки (ПЗЗ) являются жесткими ограничителями, которые нельзя игнорировать, но можно точечно корректировать в рамках КГИОП.
# *   **Социальный консенсус:** Жители центра (включая градозащитные движения) будут активно сопротивляться точечной застройке. План должен быть легитимным и учитывать мнение горожан.
#
# ### 2. Ограничения (Constraints)
#
# *   **Высотный регламент:** В центре действует жесткий высотный пояс (от 23 до 48 метров, а в зонах строгой охраны — до уровня карнизов исторических зданий). Нельзя строить небоскребы.
# *   **Плотность застройки:** Коэффициент плотности застройки (FAR) в центре уже близок к пределу. Увеличение этажности или пятна застройки запрещено на охраняемых территориях.
# *   **Транспортный коллапс:** Узкие улицы, отсутствие парковок и пробки. Уплотнение без решения транспортной проблемы приведет к параличу.
# *   **Экология:** Низкая инсоляция (солнечный свет) в дворах-колодцах, плохая вентиляция. Любое уплотнение не должно ухудшать микроклимат.
# *   **Археологический слой:** Любое строительство в центре требует археологического надзора, что удлиняет сроки и удорожает проект.
#
# ### 3. Ключевые факторы (Key Factors)
#
# 1.  **Тип уплотнения:** Не «точечная застройка» (снос исторического здания и встройка нового объема), а «реновация внутри кварталов» (использование пустырей, заброшенных промзон, неэффективных парковок и ветхих неисторических построек).
# 2.  **Функциональное назначение:** Жилье vs. Общественные пространства. Уплотнение должно быть направлено на привлечение *постоянных* жителей (а не офисов, которые создают маятниковую миграцию), чтобы центр не пустел ночью.
# 3.  **Инфраструктурная емкость:** Пропускная способность метро (станции «Садовая», «Невский проспект» перегружены) и дорог.
# 4.  **Качество среды:** Уплотнение не должно уничтожать дворы-сады и рекреационные зоны. Каждый новый квадратный метр должен сопровождаться озеленением (компенсационное озеленение на крышах или в соседних кварталах).
# 5.  **Экономика:** Стоимость земли в центре запредельна. Инвестор будет пытаться нарушить регламенты. План должен быть экономически привлекательным *в рамках правил* (например, бонусы за создание социальной инфраструктуры).
#
# ### 4. План решения (Solution Plan)
#
# **Этап 1: Аудит территории (Data Collection)**
# *   Составить карту «серых зон»: пустыри, ветхие гаражи, неиспользуемые подстанции, аварийные неисторические дома (хрущевки в центре, если они есть), промзоны («Арсенал», «Вулкан»).
# *   Выявить зоны с низкой плотностью населения (например, кварталы, где много офисов или складов).
#
# **Этап 2: Разработка принципов уплотнения (Design Principles)**
# *   **Принцип «Достройка квартала»:** Заполнение разрывов в исторической застройке (брошенные участки) зданиями-«вставками», стилистически нейтральными или современными, но строго по красной линии и с соблюдением высоты карниза.
# *   **Принцип «Надстройка»:** Разрешить надстройку мансардных этажей (при условии, что это не нарушает визуальное восприятие и не увеличивает нагрузку на фундамент). Это самый мягкий способ уплотнения.
# *   **Принцип «Реновация дворов»:** Превращение хаотичных парковок в подземные паркинги (под дворами), а на поверхности — создание общественных пространств и встроенных жилых/коммерческих блоков малой этажности (2-3 этажа) во внутренних дворах, если это не ухудшает инсоляцию соседних домов.
#
# **Этап 3: Транспортная реформа (Transportation)**
# *   Запрет на наземные парковки в центре (освобождение места под застройку).
# *   Строительство перехватывающих паркингов на въезде в центр (у станций метро «Чкаловская», «Фрунзенская»).
# *   Развитие ВСМ (внутригородских скоростных магистралей) и рельсового транспорта (трамвай) для разгрузки метро.
#
# **Этап 4: Правовая и экономическая модель (Legal & Economic)**
# *   Ввести механизм КРТ (Комплексное развитие территории) без сноса исторических зданий — только санация ветхого фонда.
# *   Установить «бонусы за плотность»: если застройщик восстанавливает фасад соседнего памятника или создает публичное пространство, ему разрешается увеличить этажность на 1-2 этажа в пределах регламента.
# *   Ввести налог на пустующие здания (стимулирование ввода в оборот).
#
# ### 5. Проверка (Verification & Validation)
#
# **Критерии успеха (KPI):**
# 1.  **Демография:** Увеличение постоянного населения центра на 15-20% без ухудшения качества жилья (проверка через 5 лет).
# 2.  **Транспорт:** Снижение времени поездки на автомобиле через центр в часы пик (цель: не более +10% к текущему времени, несмотря на рост населения).
# 3.  **Экология:** Сохранение или увеличение площади зеленых насаждений (кв. м на человека) за счет компенсационного озеленения.
# 4.  **Наследие:** Отсутствие новых объектов в списке ЮНЕСКО «под угрозой» (мониторинг ICOMOS). Нулевой снос исторических зданий.
# 5.  **Экономика:** Рост налоговых поступлений от недвижимости в центре (кадастровая стоимость должна расти, но не за счет спекуляций, а за счет реального улучшения среды).
#
# **Стресс-тесты:**
# *   Что произойдет, если инвестор обанкротится? (Нужны банковские гарантии на завершение строительства и благоустройства).
# *   Как план поведет себя при наводнении (особенно в зонах намыва, если они есть)? (Проверка гидрологических моделей).
# *   Реализуемо ли это юридически? (Проверка на соответствие 73-ФЗ и местным нормативам градпроектирования).
#
# **Итоговый вывод:**
# Уплотнение центра СПб возможно только через **интенсификацию использования существующего фонда** (надстройки, подземное пространство, ревитализация пустырей) и **жесткий запрет на точечную застройку**. Ключевой риск — транспортный коллапс, поэтому план должен начинаться не со строительства, а с реформы парковочного пространства и въездных фильтров.

# %%
print(state["output"])
# Out:
# Ниже представлен **план уплотнения центра Санкт-Петербурга**, разработанный с учётом статуса ЮНЕСКО, исторической ткани города, транспортных ограничений и социального запроса. План построен по принципу **«интенсивного, а не экстенсивного»** уплотнения — то есть не за счёт захвата новых территорий или высотных доминант, а за счёт более эффективного использования уже занятых участков.
#
# ---
#
# ## 1. Стратегическая цель
# Увеличить плотность постоянного населения и функциональную насыщенность центра **без сноса исторических зданий, без нарушения высотного регламента и без ухудшения транспортной ситуации**. Достичь роста жилого фонда на 15–20% за счёт «скрытых резервов»: надстроек, подземного пространства, ревитализации пустырей и неэффективных территорий.
#
# ---
#
# ## 2. Принципы «мягкого уплотнения»
#
# ### 2.1. Вертикальное уплотнение (без увеличения пятна застройки)
# - **Мансарды и надстройки**
#   Разрешить устройство мансардных этажей на зданиях, где это не нарушает визуальные бассейны (панорамы Невы, вид на шпили) и не превышает высоты карниза соседних домов. Условие: мансарда должна быть отступлена от фасада на 2–3 м (чтобы не искажать уличный фронт).
#   *Эффект:* +10–15% жилой площади в квартале без изменения конфигурации дворов.
#
# - **Подземное пространство**
#   Строительство подземных этажей под дворами (паркинги, склады, фитнес, коворкинги). Это позволяет вывести на поверхность зелёные общественные зоны.
#   *Ограничение:* глубина не более 2 этажей из-за археологического слоя и близости грунтовых вод (обязательно гидрологическое моделирование).
#
# ### 2.2. Заполнение лакун и «серых зон»
# Точечная застройка только на **неисторических пустырях** (бывшие гаражи, аварийные нежилые строения 1960–70-х, неиспользуемые трансформаторные подстанции).
# Условия:
# - Здание-вставка должно строго соблюдать красную линию, высоту карниза и ритм окон соседних исторических домов.
# - Фасад — нейтральный или декоративный (кирпич, штукатурка, без имитации историзма), чтобы не создавать «китч».
#
# ### 2.3. Реновация дворов-колодцев
# Превращение хаотичных парковок во дворах в **полуобщественные пространства**.
# - Под двором — подземный паркинг (с въездом с улицы, а не через арку).
# - На поверхности — мини-сквер, детская площадка, велопарковка, а также **встройки малой этажности** (1–2 этажа) для кафе, мастерских, коворкингов.
# *Критерий:* инсоляция соседних окон не должна ухудшиться более чем на 10% (солнечный калькулятор).
#
# ### 2.4. Ревитализация промышленных зон в центральной части
# Крупные бывшие заводы («Арсенал», «Вулкан», «Красное знамя» на Петроградской стороне) — перепрофилирование в лофты, апартаменты, креативные кластеры.
# - Допустимо увеличение высоты застройки на 1–2 этажа (но не выше окружающей исторической застройки) при условии сохранения исторических фасадов.
# - Обязательное создание проницаемых кварталов (общедоступные проходы и внутренние дворы).
#
# ---
#
# ## 3. Инфраструктурные меры (синхронизация)
#
# ### 3.1. Транспорт
# - **Запрет наземных парковок** на всей территории «Золотого треугольника» и вокруг Невского проспекта. Освободившиеся площади — под озеленение или малую застройку.
# - **Строительство перехватывающих паркингов** на въезде в центр: у метро «Чкаловская», «Фрунзенская», «Балтийская», «Площадь Восстания» (существующий гаражный кооператив).
# - **Развитие трамвая** по Садовой улице и набережным (выделенные линии) — как альтернатива метро, которое перегружено.
# - **Введение платного въезда** в периметр Адмиралтейского и Центрального районов в часы пик (по примеру Лондона).
#
# ### 3.2. Инженерные сети
# - **Модернизация канализации** в историческом центре (ливнёвка 1880-х годов не справляется с современной нагрузкой).
# - **Устройство локальных очистных** для каждого нового подземного паркинга (сброс в ливнёвку запрещён).
#
# ---
#
# ## 4. Правовые и экономические механизмы
#
# ### 4.1. Комплексное развитие территорий (КРТ) без сноса
# Ввести особый вид КРТ — «Реновация кварталов исторического центра»:
# - Не снос, а санация ветхих и неисторических построек.
# - Инвестор получает право на надстройку / подземный этаж и/или заполнение пустырей **только при условии** реставрации одного соседнего памятника или создания общедоступного двора-сада.
#
# ### 4.2. Бонусы за плотность (incentive zoning)
# - За каждый вновь созданный общедоступный сквер или пешеходный проход — разрешение на увеличение площади застройки на 10% (в пределах регламента).
# - За восстановление исторического фасада — возможность надстроить мансарду без прохождения повторной историко-культурной экспертизы (ускоренное согласование).
#
# ### 4.3. Налоговые меры
# - **Налог на пустующие здания** (кадастровая стоимость × 2), если объект не используется >1 года.
# - **Льготы для владельцев мансард**, которые делают их жилыми (снижение налога на имущество на 5 лет).
#
# ---
#
# ## 5. Этапы реализации (5 лет)
#
# | Год | Действия |
# |------|----------|
# | 1 | Аудит «серых зон»; принятие поправок в ПЗЗ (Закон о мансардах и подземных паркингах); запуск пилотного квартала (например, район Сенной площади). |
# | 2–3 | Строительство перехватывающих паркингов; начало реновации 3–5 дворов (подземные этажи, озеленение). |
# | 4–5 | Введение платного въезда; запуск трамвайной линии по Садовой; завершение пилотного квартала (оценка KPI). |
#
# ---
#
# ## 6. Ключевые показатели эффективности (KPI)
#
# | Показатель | Целевое значение (через 5 лет) |
# |------------|---------------------------------|
# | Прирост постоянного населения в центре | +15% |
# | Доля дворов с подземными паркингами и озеленением | 30% |
# | Сокращение наземных парковок на территории | 50% |
# | Объём нового жилья без сноса исторических зданий | 200 тыс. м² |
# | Время поездки на авто через центр в час пик | +/- 0% (не ухудшится) |
# | Площадь озеленения на человека | увеличение на 10% |
#
# ---
#
# ## 7. Риски и компенсации
#
# | Риск | Мера |
# |------|------|
# | Протесты градозащитников | Общественные слушания по каждому кварталу; запрет на любую застройку в ближайших зонах ЮНЕСКО (буферная зона). |
# | Перегрузка инженерных сетей | Строительство новых очистных и подстанций **до** разрешения любой стройки. |
# | Спекулятивный рост цен на жильё | Введение квоты на арендное жильё (10% от нового фонда — муниципальное). |
# | Нарушение археологического слоя | Обязательная археологическая экспертиза при любом подземном строительстве (финансируется девелопером). |
#
# ---
#
# ## 8. Пример «пилотного квартала»: Сенной район (между Садовой и Московским проспектом)
#
# - **Проблема:** Много пустырей и хаотичных парковок, высокий трафик, дефицит зелени.
# - **Решение:**
#   - Под двумя дворами — подземные паркинги (300 машин).
#   - Над паркингами — общественные скверы.
#   - На месте заброшенной трансформаторной подстанции — 5-этажное жилое здание-вставка (высота 23 м, как у соседних домов).
#   - Мансарды на 3 домах (по ул. Садовая) — 40 новых квартир.
# - **Результат:** +70 квартир, 0,3 га зелени, разгрузка Садовой на 15% за счёт платного въезда.
#
# ---
#
# **Заключение.**
# Уплотнение центра Санкт-Петербурга возможно только как **хирургическая операция** — точечное, медленное, с обязательной синхронизацией транспорта и сетей. Любое ускорение или нарушение высотного регламента приведёт к потере статуса ЮНЕСКО и социальному взрыву. Предложенный план делает упор на «скрытые резервы» (мансарды, подземелье, пустыри) и жёсткий контроль за соблюдением принципа «ни одного снесённого исторического здания».

# %%
state["log"]
